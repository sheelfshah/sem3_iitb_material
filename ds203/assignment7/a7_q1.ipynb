# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import sklearn.model_selection as ms

# %%
df = pd.read_excel("ENB2012_data.xlsx")

# %%
df
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %%
# checking for missing data
df.isnull().sum()
# Out:
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# X7    0
# X8    0
# Y1    0
# Y2    0
# dtype: int64

# %%
# separating Y
df_y1 = df["Y1"]
df_y2 = df["Y2"]

# %%
# dropping Y columns
df.drop(["Y1", "Y2"], axis=1, inplace=True)

# %%
# split into train and test sets
train_size=0.8
X_train1, X_test1, y_train1, y_test1 = ms.train_test_split(df.to_numpy(), df_y1.to_numpy(), train_size=train_size)
X_train2, X_test2, y_train2, y_test2 = ms.train_test_split(df.to_numpy(), df_y2.to_numpy(), train_size=train_size)

# %%
# fit normalizer on training set and use it to transform test set
normalizer1 = StandardScaler()  
X_train_norm1 = normalizer1.fit_transform(X_train1)
X_test_norm1 = normalizer1.transform(X_test1)
normalizer2 = StandardScaler()  
X_train_norm2 = normalizer2.fit_transform(X_train2)
X_test_norm2 = normalizer2.transform(X_test2)

# %%
import sklearn.linear_model as lm
from sklearn.metrics import r2_score, mean_squared_error

# %%
lin_reg1 = lm.LinearRegression()
lin_reg1.fit(X_train_norm1, y_train1)
print("Coefficients:", lin_reg1.coef_)
print("Intercept:", lin_reg1.intercept_)
# Out:
# Coefficients: [-7.15980902e+00  1.52151572e+13 -7.54891248e+12 -1.56715563e+13
#   7.44042969e+00 -1.73233032e-01  2.61254883e+00  4.58145142e-01]
# Intercept: 22.255443268970847

# %%
lin_reg2 = lm.LinearRegression()
lin_reg2.fit(X_train_norm2, y_train2)
print("Coefficients:", lin_reg2.coef_)
print("Intercept:", lin_reg2.intercept_)
# Out:
# Coefficients: [-7.81397655e+00  5.09013701e+12 -2.56716428e+12 -5.22748846e+12
#   7.55615234e+00  1.33651733e-01  1.86045074e+00  1.26502991e-01]
# Intercept: 24.71692730233661

# %%
y_pred1 = lin_reg1.predict(X_test_norm1)
print(y_pred1)
# Out:
# [36.43708389 17.33942764 12.69294327 16.62116593 39.98200577 12.5254628
#  36.74958389 35.35686844 11.89299362 29.49378555 26.15388077 30.54206436
#  28.25801437 10.75837296 26.75410812  7.45612686 32.68024796  9.70954483
#  36.05085343 35.91022843 40.12263077 27.75153702 37.19099014 17.96052139
#  31.15143936 15.39216202 35.20061844 26.8848378  30.29893082 16.01179093
#  12.47419327 26.91035812 19.46442764 27.31013077 25.58552139 10.70158737
#  37.34724014 30.73643082 16.14411514 11.9066655  13.60114639 28.10176437
#  32.89557999 39.21247452 35.7676503  28.81403702 32.90925186 15.75593155
#  19.00934952 11.59333389 13.23688858  6.99274796 15.32575577 16.46491593
#  31.58893936  9.68513077 31.82962387 14.84772843 26.31013077 35.05804031
#  36.66218155 15.16950577 10.85505264 35.00934952 17.77888077 11.76325577
#   5.68708389 11.90583389 12.20549362 13.80231827 16.53278702 16.06403702
#  12.3692128   9.23005264  9.84431046 10.44587296 28.06403702  9.53571671
#  12.16169327 30.32966202  9.86579483 19.15192764 12.78181046 14.52497452
#  13.06989639  9.13044327 32.92969101 30.79938858 28.3023793   9.38630264
#  11.86481827 32.91797226 27.8336293  36.58161514  9.52888077  8.36286514
#  40.57575577 32.12649887 12.64118546 14.87263077 14.79645889 33.64997452
#  31.65774887 11.94099014 10.74470108 30.55378311 26.29450577 34.88811844
#  35.1582753  28.34528702 12.92438858 30.13434952 15.70466202 12.6817128
#  33.37109726 24.97614639 14.38239639 15.31647843 17.18317764 14.39875382
#  30.38581436 13.30231827 12.02106827 27.15388077 35.3145253  32.45612686
#  15.29328507 14.5645253  24.99177139 31.09919327 34.16546219 11.15388077
#  13.21247452 14.4082753  31.04893082 18.22482651 33.94684952 32.76862686
#  28.77302139 30.24128311 28.1305043  17.45724838 30.08503311 15.30085343
#  32.00104874 34.60491531 27.22285812 31.27643936 18.06857651 13.00544327
#  10.55817764 12.55036514 32.06940811 34.85505264]

# %%
y_pred2 = lin_reg2.predict(X_test_norm2)
print(y_pred2)
# Out:
# [15.49720074 35.93763043 13.29163433 36.21604992 17.03976895 17.83606793
#  28.55635144 17.9410484  17.11341168 27.27918316 34.4278648  35.85462261
#  17.78186871 32.06629254 32.31521298 17.98548199 37.7794273  17.23352886
#  31.90711285 15.18128277 13.4566734  14.51575543 12.67347027 33.83865811
#  18.96501232 36.17884136 34.32444073 34.52072979 17.70862652 15.86585308
#  32.2313316  18.14368511 34.70520855 31.71615292 33.79431988 31.70252301
#  17.64075543 35.60618664 31.9500816  16.02112652 27.89051129 16.68421246
#  27.72449566 14.64319683 17.75403668 19.37321545 14.50417782 16.05970074
#  31.53797222 12.30432965 19.01091076 15.69983746 31.70301129 36.75208355
#  29.89881207 18.39173199 13.43665386 18.15052105 31.90125347 34.57849957
#  19.83606793 19.19788433 10.92298199 13.89173199 19.8809898  32.15418316
#  15.58313824 19.44593121 19.47376324 19.24280621 40.0684898  34.78162457
#  15.61780621 38.26966168 28.67744519 14.95437313 31.79183651 14.94851376
#  14.27454449 13.8184898  14.13294293 13.36780621 13.80970074 30.02478863
#  35.64427258 14.66921688 17.20480801 33.4768417  30.26204373 14.99343563
#  28.3151405  12.3004234  31.86756207 31.18811871 15.53919293 35.81653668
#  15.42932965 19.75403668 38.05970074 32.53162457 40.07434918 36.01282574
#  19.33415295 32.27712704 19.32581402 33.96609951 16.84925152 31.83675839
#  36.05052258 33.92117764 29.77185894 14.74538876 17.51966168 32.23220516
#  13.55774761 31.58871151 32.35329891 28.31287457 37.15906597 36.87293316
#  38.02747418 35.72679211 36.94934918 27.52137066 32.6141441  17.42737652
#  12.46936871 19.68811871 32.3093536  13.24282147 29.65076519 29.98035504
#  16.14173199 12.3863609  12.22815777 29.57361676 34.31760479 18.84489514
#  33.84549404 13.99280621 17.99524761 18.02307965 19.4552467  27.80750347
#  31.67123104 14.78933407 25.77674176 11.62415386 13.63050152 27.44422222
#  12.17981793 29.40857769 15.66028668 31.51253582]

# %%
print("R2 score:", r2_score(y_test1, y_pred1), "MSE:", mean_squared_error(y_test1, y_pred1))
# Out:
# R2 score: 0.9284523760112272 MSE: 7.508837694384796

# %%
print("R2 score:", r2_score(y_test2, y_pred2), "MSE:", mean_squared_error(y_test2, y_pred2))
# Out:
# R2 score: 0.8787614919792446 MSE: 10.423477275396106

# %%
# combining into one function
def train_lin_reg(df, df_y, train_size):
    X_train, X_test, y_train, y_test = ms.train_test_split(df.to_numpy(), df_y.to_numpy(), train_size=train_size)
    normalizer = StandardScaler()  
    X_train_norm = normalizer.fit_transform(X_train)
    X_test_norm = normalizer.transform(X_test)
    lin_reg = lm.LinearRegression()
    lin_reg.fit(X_train_norm, y_train)
    y_pred = lin_reg.predict(X_test_norm)
    print("R2 score:", r2_score(y_test, y_pred), "MSE:", mean_squared_error(y_test, y_pred))

# %%
print("Y1: Heating Load")
train_lin_reg(df, df_y1, train_size=0.8)
print("Y2: Cooling Load")
train_lin_reg(df, df_y2, train_size=0.8)
# Out:
# Y1: Heating Load
# R2 score: 0.896893261620882 MSE: 9.99256268600281
# Y2: Cooling Load
# R2 score: 0.8811765020684744 MSE: 11.46847086165892

# %%
train_sizes=[0.6, 0.7, 0.8, 0.9]
for ts in train_sizes:
    print(ts, ":")
    print("Y1: Heating Load")
    train_lin_reg(df, df_y1, train_size=ts)
    print("Y2: Cooling Load")
    train_lin_reg(df, df_y2, train_size=ts)
    print()
# Out:
# 0.6 :
# Y1: Heating Load
# R2 score: 0.9032413528217504 MSE: 8.982122140120442
# Y2: Cooling Load
# R2 score: 0.8676639084307091 MSE: 12.144221702616626
#
# 0.7 :
# Y1: Heating Load
# R2 score: 0.9300778124286306 MSE: 6.600096577447969
# Y2: Cooling Load
# R2 score: 0.8767595636553907 MSE: 10.996678205865047
#
# 0.8 :
# Y1: Heating Load
# R2 score: 0.9213906646078343 MSE: 7.6187222733655
# Y2: Cooling Load
# R2 score: 0.871278473661174 MSE: 12.886611416104735
#
# 0.9 :
# Y1: Heating Load
# R2 score: 0.9207094526550305 MSE: 8.108337305920458
# Y2: Cooling Load
# R2 score: 0.8811006888168625 MSE: 10.009335659179218

# %%
# 0.6 is suitable for Y1
# 0.8 is suitable for Y2

# %%
def train_ridge_reg(df, df_y, lam, train_size=0.8):
    X_train, X_test, y_train, y_test = ms.train_test_split(df.to_numpy(), df_y.to_numpy(), train_size=train_size)
    normalizer = StandardScaler()  
    X_train_norm = normalizer.fit_transform(X_train)
    X_test_norm = normalizer.transform(X_test)
    ridge_reg = lm.Ridge(alpha = lam)
    ridge_reg.fit(X_train_norm, y_train)
    y_pred = ridge_reg.predict(X_test_norm)
    print("R2 score:", r2_score(y_test, y_pred), "MSE:", mean_squared_error(y_test, y_pred))

# %%
lam_vals= [0.001, 0.005, 0.01, 0.05, 0.1, 0.5]
for ts in train_sizes:
    for lam in lam_vals:
        print(lam, ts)
        print("Y1: Heating Load")
        train_ridge_reg(df, df_y1, lam, ts)
        print("Y2: Cooling Load")
        train_ridge_reg(df, df_y2, lam, ts)
        print()
# Out:
# 0.001 0.6
# Y1: Heating Load
# R2 score: 0.8999131499095414 MSE: 9.306751269102758
# Y2: Cooling Load
# R2 score: 0.8791506262325969 MSE: 10.832369373457908
#
# 0.005 0.6
# Y1: Heating Load
# R2 score: 0.9109504217823682 MSE: 8.661372235567363
# Y2: Cooling Load
# R2 score: 0.8829492427047823 MSE: 10.633848294149216
#
# 0.01 0.6
# Y1: Heating Load
# R2 score: 0.914394973654231 MSE: 9.055081401528165
# Y2: Cooling Load
# R2 score: 0.8893308659411122 MSE: 10.30360977154866
#
# 0.05 0.6
# Y1: Heating Load
# R2 score: 0.9172677284767289 MSE: 8.566427279274762
# Y2: Cooling Load
# R2 score: 0.8759204670513081 MSE: 12.547912191185059
#
# 0.1 0.6
# Y1: Heating Load
# R2 score: 0.9137776354161387 MSE: 8.73718045996048
# Y2: Cooling Load
# R2 score: 0.8939539425173161 MSE: 9.448489118845787
#
# 0.5 0.6
# Y1: Heating Load
# R2 score: 0.920955709255436 MSE: 7.556431305724006
# Y2: Cooling Load
# R2 score: 0.8990759960308702 MSE: 9.393423541732188
#
# 0.001 0.7
# Y1: Heating Load
# R2 score: 0.9175312545241032 MSE: 7.663531231534092
# Y2: Cooling Load
# R2 score: 0.8735101895847974 MSE: 10.416693452719505
#
# 0.005 0.7
# Y1: Heating Load
# R2 score: 0.9076941952406495 MSE: 9.602601236427
# Y2: Cooling Load
# R2 score: 0.8824212022000275 MSE: 10.210337266221686
#
# 0.01 0.7
# Y1: Heating Load
# R2 score: 0.9126872486960835 MSE: 8.831448699310984
# Y2: Cooling Load
# R2 score: 0.8681658652486425 MSE: 12.35330542201494
#
# 0.05 0.7
# Y1: Heating Load
# R2 score: 0.926090813993128 MSE: 7.290187079231616
# Y2: Cooling Load
# R2 score: 0.8543294875550577 MSE: 12.277405381748618
#
# 0.1 0.7
# Y1: Heating Load
# R2 score: 0.9243832992213974 MSE: 7.77757212526759
# Y2: Cooling Load
# R2 score: 0.8762065594274929 MSE: 10.744239333134848
#
# 0.5 0.7
# Y1: Heating Load
# R2 score: 0.9056507530406935 MSE: 9.603898194712368
# Y2: Cooling Load
# R2 score: 0.89589008580049 MSE: 9.241981913743883
#
# 0.001 0.8
# Y1: Heating Load
# R2 score: 0.90439275422218 MSE: 9.138584831252254
# Y2: Cooling Load
# R2 score: 0.8955772544662965 MSE: 10.471378077817775
#
# 0.005 0.8
# Y1: Heating Load
# R2 score: 0.9026267402609709 MSE: 9.454276412778457
# Y2: Cooling Load
# R2 score: 0.8747484886815255 MSE: 11.054906817391128
#
# 0.01 0.8
# Y1: Heating Load
# R2 score: 0.9023594884699624 MSE: 9.529723615687214
# Y2: Cooling Load
# R2 score: 0.8691455276435844 MSE: 10.82899900931266
#
# 0.05 0.8
# Y1: Heating Load
# R2 score: 0.9251214644764405 MSE: 7.0219571775708385
# Y2: Cooling Load
# R2 score: 0.8746981374072597 MSE: 11.183591240777835
#
# 0.1 0.8
# Y1: Heating Load
# R2 score: 0.9123612995327101 MSE: 8.725211454137751
# Y2: Cooling Load
# R2 score: 0.888349420814532 MSE: 11.311759275336794
#
# 0.5 0.8
# Y1: Heating Load
# R2 score: 0.8862237306377448 MSE: 10.931542463529365
# Y2: Cooling Load
# R2 score: 0.8957128380268514 MSE: 9.446342711026183
#
# 0.001 0.9
# Y1: Heating Load
# R2 score: 0.9196596169944388 MSE: 8.839865312554696
# Y2: Cooling Load
# R2 score: 0.8838964031238254 MSE: 11.44051827428516
#
# 0.005 0.9
# Y1: Heating Load
# R2 score: 0.9290497038993941 MSE: 7.628915273292875
# Y2: Cooling Load
# R2 score: 0.8732276648635474 MSE: 10.43914740418524
#
# 0.01 0.9
# Y1: Heating Load
# R2 score: 0.9057999935265721 MSE: 10.14718107837723
# Y2: Cooling Load
# R2 score: 0.9163599645819623 MSE: 7.433374450683872
#
# 0.05 0.9
# Y1: Heating Load
# R2 score: 0.8861370138808466 MSE: 12.389030320157541
# Y2: Cooling Load
# R2 score: 0.860243695977072 MSE: 12.608187766107715
#
# 0.1 0.9
# Y1: Heating Load
# R2 score: 0.9153731461269691 MSE: 8.054620138025264
# Y2: Cooling Load
# R2 score: 0.8525393059611873 MSE: 14.166579810970774
#
# 0.5 0.9
# Y1: Heating Load
# R2 score: 0.9226590769305059 MSE: 9.169448947555088
# Y2: Cooling Load
# R2 score: 0.9049958802128522 MSE: 8.40833984288765

# %%
def train_lasso_reg(df, df_y, lam, train_size=0.8):
    X_train, X_test, y_train, y_test = ms.train_test_split(df.to_numpy(), df_y.to_numpy(), train_size=train_size)
    normalizer = StandardScaler()  
    X_train_norm = normalizer.fit_transform(X_train)
    X_test_norm = normalizer.transform(X_test)
    lasso_reg = lm.Lasso(alpha = lam, max_iter=5000)
    lasso_reg.fit(X_train_norm, y_train)
    y_pred = lasso_reg.predict(X_test_norm)
    print("R2 score:", r2_score(y_test, y_pred), "MSE:", mean_squared_error(y_test, y_pred))

# %%
lam_vals= [0.001, 0.005, 0.01, 0.05, 0.1, 0.5]
for ts in train_sizes:
    for lam in lam_vals:
        print(lam, ts)
        print("Y1: Heating Load")
        train_lasso_reg(df, df_y1, lam, ts)
        print("Y2: Cooling Load")
        train_lasso_reg(df, df_y2, lam, ts)
        print()
# Out:
# 0.001 0.6
# Y1: Heating Load
# R2 score: 0.9157872058541123 MSE: 8.808616202808128
# Y2: Cooling Load
# R2 score: 0.8858491748009719 MSE: 9.652545735343754
#
# 0.005 0.6
# Y1: Heating Load
# R2 score: 0.9181635491467758 MSE: 8.386229658053882
# Y2: Cooling Load
# R2 score: 0.8876665327491209 MSE: 9.487432268373873
#
# 0.01 0.6
# Y1: Heating Load
# R2 score: 0.9116169148484312 MSE: 9.643189998989982
# Y2: Cooling Load
# R2 score: 0.8823039292644834 MSE: 10.35012604974389
#
# 0.05 0.6
# Y1: Heating Load
# R2 score: 0.9137389611869418 MSE: 9.354018625111305
# Y2: Cooling Load
# R2 score: 0.8802048936949333 MSE: 11.083205778142728
#
# 0.1 0.6
# Y1: Heating Load
# R2 score: 0.9015358098656707 MSE: 10.110307236626626
# Y2: Cooling Load
# R2 score: 0.8764299660501468 MSE: 11.996083382301268
#
# 0.5 0.6
# Y1: Heating Load
# R2 score: 0.8931408547534223 MSE: 10.698220499535038
# Y2: Cooling Load
# R2 score: 0.8596673273570512 MSE: 12.93178451069473
#
# 0.001 0.7
# Y1: Heating Load
# R2 score: 0.9129602894309448 MSE: 8.651725571522979
# Y2: Cooling Load
# R2 score: 0.880895747235194 MSE: 11.032499060531897
#
# 0.005 0.7
# Y1: Heating Load
# R2 score: 0.9149342109423783 MSE: 8.720332423282882
# Y2: Cooling Load
# R2 score: 0.8728893317649807 MSE: 11.267264707341642
#
# 0.01 0.7
# Y1: Heating Load
# R2 score: 0.9039644357402761 MSE: 9.433720606863057
# Y2: Cooling Load
# R2 score: 0.8891861940011241 MSE: 9.742005828154232
#
# 0.05 0.7
# Y1: Heating Load
# R2 score: 0.9203831095207502 MSE: 8.166500698685676
# Y2: Cooling Load
# R2 score: 0.8893652450559244 MSE: 10.177499923589409
#
# 0.1 0.7
# Y1: Heating Load
# R2 score: 0.9077365836954683 MSE: 9.225989833734845
# Y2: Cooling Load
# R2 score: 0.8972880362772562 MSE: 8.667517040858327
#
# 0.5 0.7
# Y1: Heating Load
# R2 score: 0.9112819160793166 MSE: 8.807635886441314
# Y2: Cooling Load
# R2 score: 0.8999245491799591 MSE: 9.076231170901
#
# 0.001 0.8
# Y1: Heating Load
# R2 score: 0.9140892281767647 MSE: 8.804181263317012
# Y2: Cooling Load
# R2 score: 0.8918588709742539 MSE: 10.020078489648606
#
# 0.005 0.8
# Y1: Heating Load
# R2 score: 0.8901348326100185 MSE: 10.96577905792458
# Y2: Cooling Load
# R2 score: 0.8880167857527487 MSE: 10.24736281424752
#
# 0.01 0.8
# Y1: Heating Load
# R2 score: 0.9154052264192822 MSE: 8.463233653161588
# Y2: Cooling Load
# R2 score: 0.8644130271049524 MSE: 11.734286215273944
#
# 0.05 0.8
# Y1: Heating Load
# R2 score: 0.9193140495411113 MSE: 8.781342791166665
# Y2: Cooling Load
# R2 score: 0.8721151830976488 MSE: 10.632292053122365
#
# 0.1 0.8
# Y1: Heating Load
# R2 score: 0.9184840967611666 MSE: 7.685545717286444
# Y2: Cooling Load
# R2 score: 0.88743111667762 MSE: 10.645071048397227
#
# 0.5 0.8
# Y1: Heating Load
# R2 score: 0.9067956008571941 MSE: 8.832077653358086
# Y2: Cooling Load
# R2 score: 0.869622416853213 MSE: 13.045705412750705
#
# 0.001 0.9
# Y1: Heating Load
# R2 score: 0.9090525965716963 MSE: 8.043339239318039
# Y2: Cooling Load
# R2 score: 0.8572956613354275 MSE: 13.673950511902923
#
# 0.005 0.9
# Y1: Heating Load
# R2 score: 0.9385064129498328 MSE: 6.36250649451252
# Y2: Cooling Load
# R2 score: 0.8877636456304431 MSE: 8.781220898853412
#
# 0.01 0.9
# Y1: Heating Load
# R2 score: 0.9250113447374447 MSE: 8.315887973767463
# Y2: Cooling Load
# R2 score: 0.8965133506039717 MSE: 9.559726953848447
#
# 0.05 0.9
# Y1: Heating Load
# R2 score: 0.9166369828351765 MSE: 8.60804274045631
# Y2: Cooling Load
# R2 score: 0.8826981079447153 MSE: 10.8124374749885
#
# 0.1 0.9
# Y1: Heating Load
# R2 score: 0.8832113945441195 MSE: 12.50648132186336
# Y2: Cooling Load
# R2 score: 0.851397291516947 MSE: 10.870779995738301
#
# 0.5 0.9
# Y1: Heating Load
# R2 score: 0.8915488071272266 MSE: 13.839684910828407
# Y2: Cooling Load
# R2 score: 0.8853035749589123 MSE: 9.157789909901533
